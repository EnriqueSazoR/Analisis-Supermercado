# %% [markdown]
# # **Análisis Exploratorio De Datos**

# %%
import pandas as pd

# %% [markdown]
# # Importación De Datos

# %%
# DataSet Número 1
ruta = r"C:\TuRuta\Ventas Supermercados\Data\annex1.csv"
DataSet1 = pd.read_csv(ruta)
DataSet1
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %%
DataSet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Category Code  251 non-null    int64
#  3   Category Name  251 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 8.0+ KB

# %%
DataSet1.isnull().sum()
    # El DataSet no presenta nulos, así que no se realizará
    # ningún tipo de transformación edución de datos.
    # Se exportará tal y como está a una tabla en PostgreSQL.
# Out:
# Item Code        0
# Item Name        0
# Category Code    0
# Category Name    0
# dtype: int64

# %%
AgruparCategorias = DataSet1.groupby("Category Name").count()
AgruparCategorias
# Out:
#                              Item Code  Item Name  Category Code
# Category Name
# Aquatic Tuberous Vegetables         19         19             19
# Cabbage                              5          5              5
# Capsicum                            45         45             45
# Edible Mushroom                     72         72             72
# Flower/Leaf Vegetables             100        100            100
# Solanum                             10         10             10

# %%
# Exportar DataSet
DataSet1.to_csv("../Data_Limpia/Productos.csv", index=False)

# %%
# Importación de módulo y crear conexión
from sqlalchemy import create_engine

conexion = create_engine(
    "postgresql+psycopg2://ususario:Password@localhost:5432/Nombre de Base de Datos"
)

# %%
# Enviar DataSet a PostgreSQL
DataSet1.to_sql(
    "Productos",
    con=conexion,
    schema="DataSupermercado",
    if_exists="replace",
    index=False
)
# Out:
# 251
